# %% [markdown]
# <a href="https://colab.research.google.com/github/ekunal864-afk/cs-1281/blob/main/2502110067_LAB_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python")
# Out:
# python

# %%
print("python"+"programming")
# Out:
# pythonprogramming

# %% [markdown]
# Basic data type for python programming
# .float
# .int
# .string

# %%
type(8)
# Out:
# int

# %%
type(5.7)
# Out:
# float

# %%
type("kunal")
# Out:
# str

# %%
number_1 = int(input("enter first number :"))
number_2 = int(input("enter second number :"))
sum = number_1 + number_2
print(sum)
# Out:
# enter first number :69
# enter second number :1
# 70

# %%
counter = 0

for _ in range(5):
    print("The ceremony is performed.")
    counter = counter + 1

print("Final report: The ceremony was performed", counter, "times.")
# Out:
# The ceremony is performed.
# The ceremony is performed.
# The ceremony is performed.
# The ceremony is performed.
# The ceremony is performed.
# Final report: The ceremony was performed 5 times.

# %%
num_1 = int(input("enter the first number:"))
num_2 = int(input("enter the second number:"))
difference = num_1 - num_2
print(difference)
# Out:
# enter the first number:70
# enter the second number:5
# 65

# %%
num_1 = int(input("enter  the first numbers:"))
num_2 = int(input("enter  the first numbers:"))
mul = num_1 * num_2
print(mul)
# Out:
# enter  the first numbers:10
# enter  the first numbers:67
# 670

# %%
num_1 = int(input("enter  the first numbers:"))
num_2 = int(input("enter  the second numbers:"))
divide = num_1 / num_2
print(divide)
# Out:
# enter  the first numbers:12
# enter  the second numbers:2
# 6.0

# %%
num_1 = int(input("enter  the first numbers:"))
num_2 = int(input("enter  the second numbers:"))
remainder = num_1 % num_2
print(remainder)
# Out:
# enter  the first numbers:10
# enter  the second numbers:3
# 1

# %%
a = 10
b = 20
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# IMMUTABLE OBJECT
#
# .INT
# .FLOAT
# .STRING
# .BOOLEAN
# .TUPLE
#
# MULTIPLE OBJECTS
# .LIST
# .SET
# .DICTIONARY

# %% [markdown]
# LIST

# %%
my_list = [1,2,3,4,5]
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
my_list = [1,2.5,"english",True]
print(my_list)
type(my_list)
# Out:
# [1, 2.5, 'english', True]
# list

# %%
tuple_1=(2,3,4,5)
print(tuple_1)
type(tuple_1)
# Out:
# (2, 3, 4, 5)
# tuple
